# %% [markdown]
# # CLASIFICACION DE PREDICCION DE PINGUINOS

# %% [markdown]
# **Developer:** Alexander Valdez
# ***

# %%
import pandas as pd

# %%
penguins_raw = pd.read_csv('penguins_cleaned.csv')

# %%
penguins_raw
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7                181
# 1       Adelie  Torgersen            39.5           17.4                186
# 2       Adelie  Torgersen            40.3           18.0                195
# 3       Adelie  Torgersen            36.7           19.3                193
# 4       Adelie  Torgersen            39.3           20.6                190
# ..         ...        ...             ...            ...                ...
# 328  Chinstrap      Dream            55.8           19.8                207
# 329  Chinstrap      Dream            43.5           18.1                202
# 330  Chinstrap      Dream            49.6           18.2                193
# 331  Chinstrap      Dream            50.8           19.0                210
# 332  Chinstrap      Dream            50.2           18.7                198
#
#      body_mass_g     sex
# 0           3750    male
# ...

# %%
penguins = penguins_raw.drop(columns=['species'])

# %%
penguins
# Out:
#         island  bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0    Torgersen            39.1           18.7                181         3750
# 1    Torgersen            39.5           17.4                186         3800
# 2    Torgersen            40.3           18.0                195         3250
# 3    Torgersen            36.7           19.3                193         3450
# 4    Torgersen            39.3           20.6                190         3650
# ..         ...             ...            ...                ...          ...
# 328      Dream            55.8           19.8                207         4000
# 329      Dream            43.5           18.1                202         3400
# 330      Dream            49.6           18.2                193         3775
# 331      Dream            50.8           19.0                210         4100
# 332      Dream            50.2           18.7                198         3775
#
#         sex
# 0      male
# ...

# %%
encode = ['sex','island']

# %% [markdown]
# ## OPERACIONES  EN PANDAS
# ***
# * Si es axis = 0 se añade o concatena a la fila.
# * Si es axis = 1 se añade a la columna.

# %%
df =penguins

# %%
for col in encode:
    dummy = pd.get_dummies(df[col],prefix=col)
    df    = pd.concat([df,dummy],axis=1)# axis = 0 se añade o concatena a la fila
    del   df[col]                                    #pero si es axis= 1 se añade a la columan

# %% [markdown]
# Para aplicar la codificación One Hot Encoding, bastaría con pasar a la función pd.get_dummies() la Serie Pandas a codificar. Por ejemplo, podemos codificar el SEXO del pinguino, asi como tambien la isla de origen con el codigo descrito anteriormente.

# %%
df
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# 0              39.1           18.7                181         3750
# 1              39.5           17.4                186         3800
# 2              40.3           18.0                195         3250
# 3              36.7           19.3                193         3450
# 4              39.3           20.6                190         3650
# ..              ...            ...                ...          ...
# 328            55.8           19.8                207         4000
# 329            43.5           18.1                202         3400
# 330            49.6           18.2                193         3775
# 331            50.8           19.0                210         4100
# 332            50.2           18.7                198         3775
#
#      sex_female  sex_male  island_Biscoe  island_Dream  island_Torgersen
# 0             0         1              0             0                 1
# ...
